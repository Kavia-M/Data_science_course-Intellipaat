# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavia-M/Data_science_course-Intellipaat/blob/main/Python/Assignments/Time_Series_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Which of the following is not an example of a time series model?
# - Naive approach
# - Exponential smoothing
# - Moving Average
# - **None of the above**

# %% [markdown]
# 2) The below time series plot contains both Cyclical and Seasonality components
#
# ![image.png](data:image/png;base64,...)
#
#
# - FALSE
# - **TRUE**

# %% [markdown]
# 3) A set of observations recorded at an equal interval of time is called
# - Array data
# - Geometric Series
# - **Time series data**
# - Data

# %% [markdown]
# 4) In autoregressive models _______ ?
#
# - Current value of dependent variable is influenced by current values of independent variables
# - Current value of dependent variable is influenced by current and past values of independent variables
# - None of the above
# - **Current value of dependent variable is influenced by past values of both dependent and independent variables**

# %% [markdown]
# 5) I can write my custom aggregation function while resampling my time series in Pandas.
#
#
# - FALSE
# - **TRUE**

# %% [markdown]
# 6) Increase in the number of patients in the hospital due to heat stroke is:
#
# - Cyclical variation
# - Irregular variation
# - **Seasonal variation**
# - Secular trend

# %% [markdown]
# 7) The method of moving average is used to find the:
#
# - Irregular variation
# - **Secular trend**
# - Cyclical variation
# - Seasonal variation

# %% [markdown]
# 8) In moving average method we cannot find trend values of some
#
# - Middle Period
# - Starting and End Periods
# - **Starting Periods**
# - End Periods

# %% [markdown]
# 9) Time series data have a total number of components?
#
# - **4**
# - 6
# - 5
# - 3

# %% [markdown]
# 10) The best-fitted trend line is one for which sum of squares of residuals or errors is
#
# - Negative
# - 1
# - Positive
# - **Minimum**
# - Maximum

# %% [markdown]
# 11) The pacf (partial autocorrelation function) is necessary for distinguishing between ______ ?
#
# - C An MA and an ARMA is_solution: False
# - **B An AR and an ARMA is_solution: True**
# - An AR and MA model is_solution: False
# - D Different models from within the ARMA family

# %% [markdown]
# 12) Which of the following cross validation techniques is better suited for time series data?
#
# *
# 1 point
# **D Forward Chaining Cross Validation**
# k-Fold Cross Validation
# Option 3
# B Leave-one-out Cross Validation

# %% [markdown]
# 13) Which of the following statements is correct?
#
# If the autoregressive parameter (p) in an ARIMA model is 1, it means that there is no auto-correlation in the series.
#
# If the moving average component (q) in an ARIMA model is 1, it means that there is auto-correlation in the series with lag 1.
#
# - **Only 2**
# - Only 1
# - All of the statements
# - Both 1 and 2

# %% [markdown]
# 14) Which of the following is an example of a time series problem?
# Estimating number of hotel rooms booking in next 6 months.
# Estimating the total sales in the next 3 years of an insurance company.
# Estimating the number of calls for the next one week.
# - **1,2 and 3**
# - 1 and 2
# - Only 3
# - 1 and 3
# - 2 and 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
