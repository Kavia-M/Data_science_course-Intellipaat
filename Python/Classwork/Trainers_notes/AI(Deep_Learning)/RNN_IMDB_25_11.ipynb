# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavia-M/Data_science_course-Intellipaat/blob/main/Python/Classwork/Trainers_notes/AI(Deep_Learning)/RNN_IMDB_25_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📌 Problem Statement: IMDb Sentiment Classification using RNN
#
# In the previous sessions, you explored neural networks and sequential deep learning concepts. Now it’s time to apply those concepts hands-on.
#
# In this task, you will build a Recurrent Neural Network (RNN) model to classify IMDb movie reviews as positive or negative based on their text content.
#
# 🎭 About the Dataset
#
# We will be using the IMDb Dataset (Internet Movie Reviews Dataset), available directly in TensorFlow/Keras.
# It contains:
#
# Component	Details
# Total Reviews	50,000
# Labels	Binary (0 = Negative, 1 = Positive)
# Purpose	Sentiment classification
# Split	25,000 training reviews + 25,000 test reviews
#
# Every review is already converted into integer sequences, where each number represents a specific word from a vocabulary of the most frequent words.
#
# 🎯 Your Task
#
# You must:
#
# Load the IMDb dataset.
#
# Preprocess the data (padding sequences).
#
# Build an RNN-based model (You may use SimpleRNN)
#
# Train the model.
#
# Evaluate its performance using accuracy.

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,SimpleRNN,Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
num_words = 10000 #most frequent words in our data - ignoring all the rare words
(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words=num_words )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
#step-3 - pad sequenes
#step-4 - model building - sequential, embdiing,simplernn\
#step-5 - compile your model
#traing
#evaluation

# %%
#step-3 - pad sequenes

maxlen = 100
x_train  = pad_sequences(x_train,maxlen = maxlen)
x_test = pad_sequences(x_test,maxlen = maxlen)

# %%
#step-4 - model building - sequential, embdiing,simplernn\
model = Sequential()
model.add(Embedding(input_dim = num_words, output_dim= 32, input_length =maxlen))
model.add(SimpleRNN(units = 64, return_sequences= False))
model.add(Dense(1,activation= 'sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
#step-5 - compile your model
model.compile( optimizer= 'adam' ,loss = 'binary_crossentropy',metrics = ['accuracy'])

# %%
model.fit(x_train,y_train,epochs = 10,batch_size= 64,validation_split= 0.2)
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.5760 - loss: 0.6649 - val_accuracy: 0.6816 - val_loss: 0.5875
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8027 - loss: 0.4324 - val_accuracy: 0.7964 - val_loss: 0.4314
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8858 - loss: 0.2840 - val_accuracy: 0.8208 - val_loss: 0.4415
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9109 - loss: 0.2310 - val_accuracy: 0.8132 - val_loss: 0.4492
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9356 - loss: 0.1772 - val_accuracy: 0.8158 - val_loss: 0.5392
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9568 - loss: 0.1278 - val_accuracy: 0.8154 - val_loss: 0.5359
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9759 - loss: 0.0763 - val_accuracy: 0.8106 - val_loss: 0.6263
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9858 - loss: 0.0458 - val_accuracy: 0.8028 - val_loss: 0.7466
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9909 - loss: 0.0291 - val_accuracy: 0.7956 - val_loss: 0.8437
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9880 - loss: 0.0370 - val_accuracy: 0.7972 - val_loss: 0.9143
