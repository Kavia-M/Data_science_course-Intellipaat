# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavia-M/Data_science_course-Intellipaat/blob/main/Python/Classwork/Trainers_notes/Modules/Case_Study/HR_Analytics_by_Trainer(18th_June).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dataset Link : https://drive.google.com/file/d/1qmqR5REdBntdpODOsY6NROk2YMnC6Nrn/view?usp=drive_link

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/employe.csv')

# %% [markdown]
# - People Charm', a growing company is facing a high attrition rate among their employees which in turn affects their business due to the lack of experitse and experience.
# - Their HR department is assigned the task to reduce the attrition rate by retaining employees who are about to churn out from the company.
# - They need to recommend special plans or strategies which will help them to retain their employees which in turn will help them to grow bigger as a company.

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
#EDA : Exploratory Data Analysis
#1. null values
#2. duplicates
#3. creating relations between columns
#4. get inferences from dataset
#5. suggestion to improve data quality

# %%
#checking for the null values
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
#Let's suppose i had null values
#df.dropna(inplace=True)

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# np.int64(3008)

# %%
#checking for duplicate rows
df[df.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11991 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      11991 non-null  float64
#  1   lastEvaluation         11991 non-null  float64
#  2   numberOfProjects       11991 non-null  int64
#  3   avgMonthlyHours        11991 non-null  int64
#  4   timeSpent.company      11991 non-null  int64
#  5   workAccident           11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotionInLast5years  11991 non-null  int64
#  8   dept                   11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
#plot a box plot separately for the columns avgMonthlyHours,numberOfProjects,timespent.company

# %%
sns.boxplot(df['avgMonthlyHours'])
# Out:
# <Axes: ylabel='avgMonthlyHours'>

# %%
sns.boxplot(df['numberOfProjects'])
# Out:
# <Axes: ylabel='numberOfProjects'>

# %%
sns.boxplot(df['timeSpent.company'])
# Out:
# <Axes: ylabel='timeSpent.company'>

# %%
#Outlier: extreme values,don't go well with the rest of the range of data

# %%
#Aim: to find why people are about to leave the company

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
sns.countplot(data=df, x='numberOfProjects', hue='left') #hue: distinguishes data on the basis of categories of a specific column
plt.show()

# %%
sns.countplot(data=df,x='avgMonthlyHours',hue='left')
plt.show()

# %%
sns.histplot(data=df,x='avgMonthlyHours', hue='left', bins=10) #bins: number of division in a histogram
plt.show()

# %%
#most preferrable number of montly working hours is between 100-200
#avoid 300 as all people are leaving for that

# %%
sns.countplot(x=df["timeSpent.company"],hue=df["left"])
plt.show()

# %%
sns.countplot(data=df,x='promotionInLast5years',hue='left')
plt.show()

# %%
#due to lack of proper promotions employees are tending to leave the company
#try to give promotions and hikes and better treatment to retain employees for a longer period

# %%
sns.countplot(data=df,x='workAccident',hue='left')
plt.show()

# %%
#improve the work environment and safety measures

# %%
sns.countplot(data=df, x='dept', hue='left')
plt.xticks(rotation=90)
plt.show()

# %%
#more people are there in support, technical and sales dept so focus much on those as most people
#leaving are from the same

# %%
sns.countplot(data=df,x="salary",hue="left")
plt.show()

# %%
#Better give the appropriate salary for the deserving candidates since people with low salary are leaving the most

# %%
sns.barplot(data=df, x='salary',y='numberOfProjects', hue='left')
plt.show()
