# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavia-M/Data_science_course-Intellipaat/blob/main/Python/Classwork/Trainers_notes/Gen-AI/Tokenizing_for_encoder_decoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Embedding,LSTM,Dense

# %%
#step-2

eng = ["hi","hello","how are you","thank you"]
fr = ["salut", "bonjour","comment ca va","merci"]

# %%
#step-3
tok_eng = Tokenizer()
tok_eng.fit_on_texts(eng)
x= tok_eng.texts_to_sequences(eng)
x = pad_sequences(x)

# %%
x
# Out:
# array([[0, 0, 2],
#        [0, 0, 3],
#        [4, 5, 1],
#        [0, 6, 1]], dtype=int32)

# %%
#step-4
tok_fr = Tokenizer()
tok_fr.fit_on_texts(fr)
y= tok_fr.texts_to_sequences(fr)
y = pad_sequences(y)

# %%
y
# Out:
# array([[0, 0, 1],
#        [0, 0, 2],
#        [3, 4, 5],
#        [0, 0, 6]], dtype=int32)
