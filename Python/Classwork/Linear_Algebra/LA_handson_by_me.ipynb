# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavia-M/Data_science_course-Intellipaat/blob/main/Python/Classwork/Linear_Algebra/LA_handson_by_me.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
M1=np.array([[12,14,16],[10,8,6],[3,4,5]])
M2=np.array([[1,4,6],[20,18,16],[12,13,14]])

# %%
M1+M2
# Out:
# array([[13, 18, 22],
#        [30, 26, 22],
#        [15, 17, 19]])

# %%
M1
# Out:
# array([[12, 14, 16],
#        [10,  8,  6],
#        [ 3,  4,  5]])

# %%
M2
# Out:
# array([[ 1,  4,  6],
#        [20, 18, 16],
#        [12, 13, 14]])

# %%
print(M1*M2)
# Out:
# [[ 12  56  96]
#  [200 144  96]
#  [ 36  52  70]]

# %%
print(M1/M2)
# Out:
# [[12.          3.5         2.66666667]
#  [ 0.5         0.44444444  0.375     ]
#  [ 0.25        0.30769231  0.35714286]]

# %%
print(M1-M2)
# Out:
# [[ 11  10  10]
#  [-10 -10 -10]
#  [ -9  -9  -9]]

# %%
np.invert(M1)
# Out:
# array([[-13, -15, -17],
#        [-11,  -9,  -7],
#        [ -4,  -5,  -6]])

# %%
np.matmul(M1, M2)
# Out:
# array([[484, 508, 520],
#        [242, 262, 272],
#        [143, 149, 152]])

# %%
np.dot(M1, M2)
# Out:
# array([[484, 508, 520],
#        [242, 262, 272],
#        [143, 149, 152]])

# %%
M1
# Out:
# array([[12, 14, 16],
#        [10,  8,  6],
#        [ 3,  4,  5]])

# %%
M1.T
# Out:
# array([[12, 10,  3],
#        [14,  8,  4],
#        [16,  6,  5]])

# %%
M1.transpose()
# Out:
# array([[12, 10,  3],
#        [14,  8,  4],
#        [16,  6,  5]])

# %%
((M1.T.T) == M1).all()
# Out:
# np.True_

# %%
A=np.array([[12,14],[10,8]])
B=np.array([[1,4],[20,16]])
x=(A+B).T
print(x)
y=A.T+B.T
print(y)
# Out:
# [[13 30]
#  [18 24]]
# [[13 30]
#  [18 24]]

# %%
np.array_equal(M1,M2)
# Out:
# False

# %%
np.invert(M1)
# Out:
# array([[-13, -15, -17],
#        [-11,  -9,  -7],
#        [ -4,  -5,  -6]])

# %%
M1
# Out:
# array([[12, 14, 16],
#        [10,  8,  6],
#        [ 3,  4,  5]])

# %%
np.linalg.det(M2)
# Out:
# np.float64(-43.99999999999997)

# %%
np.linalg.inv(M2)
# Out:
# array([[-1.        , -0.5       ,  1.        ],
#        [ 2.        ,  1.31818182, -2.36363636],
#        [-1.        , -0.79545455,  1.40909091]])

# %%
np.invert(M2)
# Out:
# array([[ -2,  -5,  -7],
#        [-21, -19, -17],
#        [-13, -14, -15]])

# %%
A=np.array([[1,2],[2,4]])
eigVal,eigVec=np.linalg.eig(A)

# %%
A=np.array([[2,1],[1,2]])
eigVal,eigVec=np.linalg.eig(A)

# %%
eigVal
# Out:
# array([3., 1.])

# %%
eigVec
# Out:
# array([[ 0.70710678, -0.70710678],
#        [ 0.70710678,  0.70710678]])
