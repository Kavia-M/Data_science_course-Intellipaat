# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavia-M/Data_science_course-Intellipaat/blob/main/Python/Classwork/Live_Quiz/AI(Deep_Learning)/GenAI_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What was the main limitation of encoder-decoder RNN models that Transformers solved?
#     - Lack of memory capacity
#     - **Sequential dependency during training and inference**
#     - Inability to use convolution operations
#     - Too many layers
# 2. What is the key innovation introduced by Transformers to handle sequential data?
#     - A. Convolutional filters
#     - B. Recurrent connections
#     - C. **Attention mechanism**
#     - D. Dropout layers
# 3. Why is positional encoding used in Transformer models?
#     - A. To reduce model parameters
#     - B. **To represent word order information that attention alone cannot capture**
#     - C. To prevent overfitting
#     - D. To improve training speed
# 4. What do Q, K, and V stand for in the Attention mechanism?
#     - A. Quantile, Key, Value
#     - B. Query, Kernel, Vector
#     - C. **Query, Key, Value**
#     - D. Quality, Kind, Vector
# 5. What is the purpose of the Softmax function in the attention mechanism?
#     - A. **To normalize attention scores into probabilities**
#     - B. To remove outliers
#     - C. To apply activation for non-linearity
#     - D. To compress embeddings
# 6. Which part of the Transformer architecture allows the model to focus on different parts of the input simultaneously?
#     - A. Feedforward network
#     - B. **Multi-Head Attention**
#     - C. Layer Normalization
#     - D. Positional Encoding
# 7. What is Self-Attention in Transformers?
#     - A. **When each word attends to all other words in the same sequence**
#     - B. When input attends to output
#     - C. When attention is applied only between encoder and decoder
#     - D. When each token attends to only previous tokens
# 8. What is the main function of Cross-Attention in the Transformer Decoder?
#     - A. **To link the decoder input with the encoder output representations**
#     - B. To connect different decoder layers
#     - C. To attend only within the decoder sequence
#     - D. To perform residual connections
# 9. Which component ensures that Transformers process all tokens in parallel instead of sequentially?
#     - A. Attention weights
#     - B. Positional encoding
#     - C. **Lack of recurrence (no RNN structure)**
#     - D. Encoder-decoder connections
# 10. In Multi-Head Attention, why are multiple attention heads used instead of one?
#     - A. To reduce computational cost
#     - B. **To capture information from multiple representation subspaces**
#     - C. To perform parallel token encoding
#     - D. To improve dropout performance
# 11. What problem does Masked Self-Attention solve in the Transformer decoder?
#     - A. It prevents the model from attending to padding  tokens
#     - B. **It ensures the model does not look at future tokens during training**
#     - C. It reduces model parameters
#     - D. It improves positional encoding
# 12. In scaled dot-product attention, why is the dot product divided by √dₖ?
#     - A. **To stabilize gradients by preventing extremely large values**
#     - B. To make computation faster
#     - C. To reduce model size
#     - D. To normalize positional encodings
# 13. What is the advantage of removing recurrence (no RNNs) in Transformers
#     - A. Lower memory requirements
#     - B. **Parallel processing of all tokens**
#     - C. Better contextual embeddings
#     - D. More stable positional encoding
# 14. What does “Multi-Head” mean in Multi-Head Attention?
#     - A. Multiple decoders
#     - B. **Multiple sets of Q, K, V projections learned in parallel**
#     - C. Multiple feedforward layers running together
#     - D. Multiple encoders stacked
# 15. What is the role of the Encoder in a Transformer?
#     - A. Generate final output sequence
#     - B. **Convert input tokens into contextual representations**
#     - C. Predict next tokens
#     - D. Apply positional encoding
# 16. In the Transformer decoder, what triggers the use of Cross-Attention
#     - A. When decoding begins after encoder outputs are available
#     - B. **When self-attention completes**
#     - C. When positional encoding is applied
#     - D. When training ends
# 17. What happens when the attention mechanism assigns a higher weight to a token?
#     - A. The token is ignored
#     - B. **The token contributes more to the output representation**
#     - C. The token is removed from the sequence
#     - D. The token becomes the query
# 18. Why does LSTM use a sigmoid activation for gates (forget/input/output)?
#     - A. To allow negative values
#     - B. **To limit gate decisions between 0 and 1**
#     - C. To increase gradient flow
#     - D. To replace softmax
# 19. What is the role of “teacher forcing” during training?
#     - A. To reduce embedding size
#     - B. **Decoder receives the true previous token instead of its prediction**
#     - C. Encoder receives the target sequence
#     - D. To eliminate the need for recursion
# 20. Why is the encoder's last hidden state important in basic Seq2Seq?
#     - A. **It contains the compressed semantic representation of the entire input sequence**
#     - B. It stores positional encodings
#     - C. It generates softmax probabilities
#     - D. It computes Q, K, V vectors
# 21. What is the primary responsibility of the Retriever in a RAG system?
#     - A. Generate the final natural-language answer
#     - B. Convert input text into vector embeddings
#     - C. **Find the most relevant documents using similarity search**
#     - D. Apply softmax over logits
# 22. What is the purpose of Chunking documents before storing them in a vector DB?
#     - A. To reduce the size of embeddings
#     - B. **To allow retrieval of finer-grained context**
#     - C. To improve softmax accuracy
#     - D. To eliminate the need for a generator
# 23. Why is Top-K retrieval necessary in RAG?
#     - A. LLMs cannot take more than one document
#     - B. **It reduces search cost by selecting only the most relevant results**
#     - C. It avoids the use of embeddings
#     - D. It replaces positional encoding
# 24. Why does RAG reduce hallucinations in LLMs?
#     - A. It lowers model size
#     - B. **It forces the model to use externally retrieved facts as grounding**
#     - C. It removes positional encoding
#     - D. It trains the model from scratch
# 25. What is the primary purpose of an LLM?
#     - A. Compress long text into smaller embeddings
#     - B. **Generate and understand human-like text based on patterns learned from data**
#     - C. Store data like a traditional database
#     - D. Convert text into audio
